# %% [markdown]
# ---
# title: Sentinel-1 GRD Zarr Product Exploration
# subtitle: Explore how to open, inspect the metadata and visualise Sentinel-1 GRD Zarr format
# authors:
#   - name: Michele Claus
#     orcid: 0000-0003-3680-381X
#     github: clausmichele
#     affiliations:
#       - id: Eurac Research
#         institution: Eurac Research
#         ror: 01xt1w755
# date: 2025-05-28
# thumbnail: ../static/ESA_EOPF_logo_2025_COLOR_ESA_blue_reduced.png
# keywords: ["xarray", "earth observation", "remote sensing"]
# tags: ["sentinel-1", "xarray", "land"]
# releaseDate: 2025-05-28
# datePublished: 2025-05-28
# dateModified: 2025-05-28
# github: https://github.com/EOPF-Sample-Service/eopf-sample-notebooks
# license: Apache-2.0
# ---

# %% [markdown]
# ```{image} ../static/ESA_EOPF_logo_2025_COLOR_ESA_blue_reduced.png
# :alt: ESA EOPF Zarr Logo
# :width: 250px
# :align: center
# ```

# %% [markdown]
# # Sentinel-1 GRD Zarr Product Exploration

# %% [markdown]
# ## Table of Contents
# 1. [Introduction](#IntroductionGRD)
# 1. [Import modules](#ImportModulesGRD)
# 2. [File path definition](#PathGRD)
# 3. [Open the product](#OpenGRD)
# 4. [Overview of the product content](#OverviewGRD)
# 5. [Explore product geolocation](#LocationGRD)
# 6. [Data Decimation](#DecimationGRD)
# 7. [Geocoding using GCPs](#GeocodingGRD)
# 8. [Geographic selection](#SelectionGRD)
# 9. [Summary](#SummaryGRD)

# %% [markdown]
# (IntroductionGRD)=
# ## Introduction

# %% [markdown]
# This notebook demonstrates how to open, explore, and visualize Sentinel-1 GRD products stored in EOPF Zarr format, including accessing, geocoding, subsetting and plotting a single polarization.

# %% [markdown]
# :::{hint} Overview
# **Questions**
# - How do I access Sentinel-1 GRD in EOPF Zarr format?
# - How do I plot the Sentinel-1 footprint location on a map?
# - How do I plot an image of the selected scene?
#
# **Objectives**
# - Being able to open a Sentinel-1 GRD EOPF Zarr product from an object storage
# - Understanding the product structure and how to get a specific polarization
# - Being able to geocode and slice the data geographically
# :::

# %% [markdown]
# (ImportModulesGRD)=
# ## Import Modules

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

xr.set_options(display_expand_attrs=False)
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["font.size"] = 10

# %% [markdown]
# (PathGRD)=
# ## File path definition
#
# **GRD**: S1A_IW_GRDH_1SDV_20250408T164909_20250408T164934_058668_0743A7_D5AC
#
# **polarization**: VH
#
# ```{note}
# Please be aware that this notebook works only with Sentinel-1 products converted using eopf-cpm version >= 2.6.0. You can infer the version used by the product URL. Older product versions, like the ones including `cpm_v256` in the URL do not work.
# ```

# %%
remote_product_path = "https://objects.eodc.eu/e05ab01a9d56408d82ac32d69a5aae2a:notebook-data/tutorial_data/cpm_v260/S1A_IW_GRDH_1SDV_20250408T164909_20250408T164934_058668_0743A7_D5AC.zarr"

# %% [markdown]
# (OpenGRD)=
# ## Open the product
#
# The GRD product can be opened as a `DataTree` using Xarray:

# %%
dt = xr.open_datatree(remote_product_path, engine="zarr", chunks={})
dt
# Out:
# <xarray.DataTree>
# Group: /
# │   Attributes: (2)
# ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH
# │   │   Attributes: (2)
# │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/antenna_pattern
# │   │   │       Dimensions:              (azimuth_time: 27, count: 720)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time         (azimuth_time) datetime64[ns] 216B 2025-04-08T16:49:...
# │   │   │         * count                (count) int64 6kB 0 1 2 3 4 5 ... 715 716 717 718 719
# │   │   │       Data variables:
# │   │   │           elevation_angle      (azimuth_time, count) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │           incidence_angle      (azimuth_time, count) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │           roll                 (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           slant_range_time_ap  (azimuth_time, count) float64 156kB dask.array<chunksize=(27, 720), meta=np.ndarray>
# │   │   │           swath                (azimuth_time) <U3 324B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           terrain_height       (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/attitude
# │   │   │       Dimensions:       (azimuth_time: 25)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2025-04-08T16:49:09.8750...
# │   │   │       Data variables:
# │   │   │           pitch         (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q0            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q1            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q2            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           q3            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           roll          (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wx            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wy            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           wz            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   │           yaw           (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/azimuth_fm_rate
# │   │   │       Dimensions:                     (azimuth_time: 10, degree: 3)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                (azimuth_time) datetime64[ns] 80B 2025-04-08T...
# │   │   │       Dimensions without coordinates: degree
# │   │   │       Data variables:
# │   │   │           azimuth_fm_rate_polynomial  (azimuth_time, degree) float64 240B dask.array<chunksize=(10, 3), meta=np.ndarray>
# │   │   │           t0                          (azimuth_time) float64 80B dask.array<chunksize=(10,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/coordinate_conversion
# │   │   │       Dimensions:            (azimuth_time: 28, degree: 9)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time       (azimuth_time) datetime64[ns] 224B 2025-04-08T16:49:07...
# │   │   │       Dimensions without coordinates: degree
# │   │   │       Data variables:
# │   │   │           gr0                (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │   │           grsr_coefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
# │   │   │           slant_range_time   (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │   │           sr0                (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │   │           srgr_coefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/doppler_centroid
# │   │   │       Dimensions:                            (azimuth_time: 27, degree: 3)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                       (azimuth_time) datetime64[ns] 216B 202...
# │   │   │         * degree                             (degree) int64 24B 2 1 0
# │   │   │       Data variables:
# │   │   │           data_dc_polynomial                 (azimuth_time, degree) float32 324B dask.array<chunksize=(27, 3), meta=np.ndarray>
# │   │   │           data_dc_rms_error                  (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           data_dc_rms_error_above_threshold  (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           fine_dce_azimuth_start_time        (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           fine_dce_azimuth_stop_time         (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   │           geometry_dc_polynomial             (azimuth_time, degree) float32 324B dask.array<chunksize=(27, 3), meta=np.ndarray>
# │   │   │           t0                                 (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/gcp
# │   │   │       Dimensions:               (azimuth_time: 10, ground_range: 21)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time          (azimuth_time) datetime64[ns] 80B 2025-04-08T16:49:...
# │   │   │         * ground_range          (ground_range) float64 168B 0.0 ... 2.645e+05
# │   │   │           line                  (azimuth_time) uint32 40B dask.array<chunksize=(10,), meta=np.ndarray>
# │   │   │           pixel                 (ground_range) uint32 84B dask.array<chunksize=(21,), meta=np.ndarray>
# │   │   │       Data variables:
# │   │   │           azimuth_time_gcp      (azimuth_time, ground_range) datetime64[ns] 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           elevation_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           height                (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           incidence_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           latitude              (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           longitude             (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   │           slant_range_time_gcp  (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/orbit
# │   │   │       Dimensions:       (azimuth_time: 17, axis: 3)
# │   │   │       Coordinates:
# │   │   │         * axis          (axis) <U1 12B 'x' 'y' 'z'
# │   │   │         * azimuth_time  (azimuth_time) datetime64[ns] 136B 2025-04-08T16:48:02.3439...
# │   │   │       Data variables:
# │   │   │           position      (azimuth_time, axis) float64 408B dask.array<chunksize=(17, 3), meta=np.ndarray>
# │   │   │           velocity      (azimuth_time, axis) float64 408B dask.array<chunksize=(17, 3), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/reference_replica
# │   │   │       Dimensions:                                   (azimuth_time: 3, degree: 4)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                              (azimuth_time) datetime64[ns] 24B ...
# │   │   │       Dimensions without coordinates: degree
# │   │   │       Data variables:
# │   │   │           reference_replica_amplitude_coefficients  (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
# │   │   │           reference_replica_phase_coefficients      (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
# │   │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/replica
# │   │   │       Dimensions:                           (azimuth_time: 15)
# │   │   │       Coordinates:
# │   │   │         * azimuth_time                      (azimuth_time) datetime64[ns] 120B 2025...
# │   │   │       Data variables:
# │   │   │           absolute_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           cross_correlation_peak_location   (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           cross_correlation_pslr            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           internal_time_delay               (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           model_pg_product_amplitude        (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           model_pg_product_phase            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           pg_product_amplitude              (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           pg_product_phase                  (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           reconstructed_replica_valid_flag  (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   │           relative_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │   │   └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/terrain_height
# │   │           Dimensions:         (azimuth_time: 5)
# │   │           Coordinates:
# │   │             * azimuth_time    (azimuth_time) datetime64[ns] 40B 2025-04-08T16:48:59.022...
# │   │           Data variables:
# │   │               terrain_height  (azimuth_time) float64 40B dask.array<chunksize=(5,), meta=np.ndarray>
# │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/measurements
# │   │       Dimensions:       (azimuth_time: 16675, ground_range: 26450)
# │   │       Coordinates:
# │   │         * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2025-04-08T16:49:09.022...
# │   │         * ground_range  (ground_range) float64 212kB 0.0 10.0 ... 2.645e+05 2.645e+05
# │   │           line          (azimuth_time) int64 133kB dask.array<chunksize=(2048,), meta=np.ndarray>
# │   │           pixel         (ground_range) int64 212kB dask.array<chunksize=(4096,), meta=np.ndarray>
# │   │       Data variables:
# │   │           grd           (azimuth_time, ground_range) uint16 882MB dask.array<chunksize=(2048, 4096), meta=np.ndarray>
# │   └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality
# │       ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/calibration
# │       │       Dimensions:       (azimuth_time: 27, ground_range: 663)
# │       │       Coordinates:
# │       │         * azimuth_time  (azimuth_time) datetime64[ns] 216B 2025-04-08T16:49:09.0223...
# │       │         * ground_range  (ground_range) float64 5kB 0.0 6.67e+06 ... 4.409e+09 4.41e+09
# │       │           line          (azimuth_time) uint32 108B dask.array<chunksize=(27,), meta=np.ndarray>
# │       │           pixel         (ground_range) uint32 3kB dask.array<chunksize=(663,), meta=np.ndarray>
# │       │       Data variables:
# │       │           beta_nought   (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           dn            (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           gamma         (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       │           sigma_nought  (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
# │       ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise
# │       │       Dimensions:                        (azimuth_time: 797)
# │       │       Coordinates:
# │       │         * azimuth_time                   (azimuth_time) datetime64[ns] 6kB 2025-04-...
# │       │       Data variables:
# │       │           noise_power_correction_factor  (azimuth_time) float32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
# │       │           number_of_noise_lines          (azimuth_time) uint32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
# │       ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise_azimuth
# │       │       Dimensions:             (swath: 3, azimuth_time: 1686)
# │       │       Coordinates:
# │       │           first_azimuth_time  (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
# │       │           first_range_sample  (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
# │       │           last_azimuth_time   (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
# │       │           last_range_sample   (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
# │       │           line                (swath, azimuth_time) int32 20kB dask.array<chunksize=(3, 1686), meta=np.ndarray>
# │       │         * swath               (swath) <U3 36B 'IW1' 'IW2' 'IW3'
# │       │       Dimensions without coordinates: azimuth_time
# │       │       Data variables:
# │       │           noise_azimuth_lut   (swath, azimuth_time) float32 20kB dask.array<chunksize=(3, 1686), meta=np.ndarray>
# │       └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise_range
# │               Dimensions:          (azimuth_time: 26, ground_range: 666)
# │               Coordinates:
# │                 * azimuth_time     (azimuth_time) datetime64[ns] 208B 2025-04-08T16:49:09.0...
# │                   ground_range     (azimuth_time, ground_range) float64 139kB dask.array<chunksize=(26, 666), meta=np.ndarray>
# │                   line             (azimuth_time) int32 104B dask.array<chunksize=(26,), meta=np.ndarray>
# │                   pixel            (azimuth_time, ground_range) int32 69kB dask.array<chunksize=(26, 666), meta=np.ndarray>
# │               Data variables:
# │                   noise_range_lut  (azimuth_time, ground_range) float32 69kB dask.array<chunksize=(26, 666), meta=np.ndarray>
# └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV
#     │   Attributes: (2)
#     ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/antenna_pattern
#     │   │       Dimensions:              (azimuth_time: 27, count: 720)
#     │   │       Coordinates:
#     │   │         * azimuth_time         (azimuth_time) datetime64[ns] 216B 2025-04-08T16:49:...
#     │   │         * count                (count) int64 6kB 0 1 2 3 4 5 ... 715 716 717 718 719
#     │   │       Data variables:
#     │   │           elevation_angle      (azimuth_time, count) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │           incidence_angle      (azimuth_time, count) float32 78kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │           roll                 (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           slant_range_time_ap  (azimuth_time, count) float64 156kB dask.array<chunksize=(27, 720), meta=np.ndarray>
#     │   │           swath                (azimuth_time) <U3 324B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           terrain_height       (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/attitude
#     │   │       Dimensions:       (azimuth_time: 25)
#     │   │       Coordinates:
#     │   │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2025-04-08T16:49:09.8750...
#     │   │       Data variables:
#     │   │           pitch         (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q0            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q1            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q2            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           q3            (azimuth_time) float32 100B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           roll          (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wx            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wy            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           wz            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   │           yaw           (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/azimuth_fm_rate
#     │   │       Dimensions:                     (azimuth_time: 10, degree: 3)
#     │   │       Coordinates:
#     │   │         * azimuth_time                (azimuth_time) datetime64[ns] 80B 2025-04-08T...
#     │   │       Dimensions without coordinates: degree
#     │   │       Data variables:
#     │   │           azimuth_fm_rate_polynomial  (azimuth_time, degree) float64 240B dask.array<chunksize=(10, 3), meta=np.ndarray>
#     │   │           t0                          (azimuth_time) float64 80B dask.array<chunksize=(10,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/coordinate_conversion
#     │   │       Dimensions:            (azimuth_time: 28, degree: 9)
#     │   │       Coordinates:
#     │   │         * azimuth_time       (azimuth_time) datetime64[ns] 224B 2025-04-08T16:49:07...
#     │   │       Dimensions without coordinates: degree
#     │   │       Data variables:
#     │   │           gr0                (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
#     │   │           grsr_coefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
#     │   │           slant_range_time   (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
#     │   │           sr0                (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
#     │   │           srgr_coefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/doppler_centroid
#     │   │       Dimensions:                            (azimuth_time: 27, degree: 3)
#     │   │       Coordinates:
#     │   │         * azimuth_time                       (azimuth_time) datetime64[ns] 216B 202...
#     │   │         * degree                             (degree) int64 24B 2 1 0
#     │   │       Data variables:
#     │   │           data_dc_polynomial                 (azimuth_time, degree) float32 324B dask.array<chunksize=(27, 3), meta=np.ndarray>
#     │   │           data_dc_rms_error                  (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           data_dc_rms_error_above_threshold  (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           fine_dce_azimuth_start_time        (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           fine_dce_azimuth_stop_time         (azimuth_time) bool 27B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   │           geometry_dc_polynomial             (azimuth_time, degree) float32 324B dask.array<chunksize=(27, 3), meta=np.ndarray>
#     │   │           t0                                 (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/gcp
#     │   │       Dimensions:               (azimuth_time: 10, ground_range: 21)
#     │   │       Coordinates:
#     │   │         * azimuth_time          (azimuth_time) datetime64[ns] 80B 2025-04-08T16:49:...
#     │   │         * ground_range          (ground_range) float64 168B 0.0 ... 2.645e+05
#     │   │           line                  (azimuth_time) uint32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     │   │           pixel                 (ground_range) uint32 84B dask.array<chunksize=(21,), meta=np.ndarray>
#     │   │       Data variables:
#     │   │           azimuth_time_gcp      (azimuth_time, ground_range) datetime64[ns] 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           elevation_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           height                (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           incidence_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           latitude              (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           longitude             (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   │           slant_range_time_gcp  (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/orbit
#     │   │       Dimensions:       (azimuth_time: 17, axis: 3)
#     │   │       Coordinates:
#     │   │         * axis          (axis) <U1 12B 'x' 'y' 'z'
#     │   │         * azimuth_time  (azimuth_time) datetime64[ns] 136B 2025-04-08T16:48:02.3439...
#     │   │       Data variables:
#     │   │           position      (azimuth_time, axis) float64 408B dask.array<chunksize=(17, 3), meta=np.ndarray>
#     │   │           velocity      (azimuth_time, axis) float64 408B dask.array<chunksize=(17, 3), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/reference_replica
#     │   │       Dimensions:                                   (azimuth_time: 3, degree: 4)
#     │   │       Coordinates:
#     │   │         * azimuth_time                              (azimuth_time) datetime64[ns] 24B ...
#     │   │       Dimensions without coordinates: degree
#     │   │       Data variables:
#     │   │           reference_replica_amplitude_coefficients  (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     │   │           reference_replica_phase_coefficients      (azimuth_time, degree) float32 48B dask.array<chunksize=(3, 4), meta=np.ndarray>
#     │   ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/replica
#     │   │       Dimensions:                           (azimuth_time: 15)
#     │   │       Coordinates:
#     │   │         * azimuth_time                      (azimuth_time) datetime64[ns] 120B 2025...
#     │   │       Data variables:
#     │   │           absolute_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           cross_correlation_peak_location   (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           cross_correlation_pslr            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           internal_time_delay               (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           model_pg_product_amplitude        (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           model_pg_product_phase            (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           pg_product_amplitude              (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           pg_product_phase                  (azimuth_time) float32 60B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           reconstructed_replica_valid_flag  (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   │           relative_pg_product_valid_flag    (azimuth_time) bool 15B dask.array<chunksize=(15,), meta=np.ndarray>
#     │   └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/conditions/terrain_height
#     │           Dimensions:         (azimuth_time: 5)
#     │           Coordinates:
#     │             * azimuth_time    (azimuth_time) datetime64[ns] 40B 2025-04-08T16:48:59.022...
#     │           Data variables:
#     │               terrain_height  (azimuth_time) float64 40B dask.array<chunksize=(5,), meta=np.ndarray>
#     ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/measurements
#     │       Dimensions:       (azimuth_time: 16675, ground_range: 26450)
#     │       Coordinates:
#     │         * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2025-04-08T16:49:09.022...
#     │         * ground_range  (ground_range) float64 212kB 0.0 10.0 ... 2.645e+05 2.645e+05
#     │           line          (azimuth_time) int64 133kB dask.array<chunksize=(2048,), meta=np.ndarray>
#     │           pixel         (ground_range) int64 212kB dask.array<chunksize=(4096,), meta=np.ndarray>
#     │       Data variables:
#     │           grd           (azimuth_time, ground_range) uint16 882MB dask.array<chunksize=(2048, 4096), meta=np.ndarray>
#     └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/quality
#         ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/quality/calibration
#         │       Dimensions:       (azimuth_time: 27, ground_range: 663)
#         │       Coordinates:
#         │         * azimuth_time  (azimuth_time) datetime64[ns] 216B 2025-04-08T16:49:09.0223...
#         │         * ground_range  (ground_range) float64 5kB 0.0 6.67e+06 ... 4.409e+09 4.41e+09
#         │           line          (azimuth_time) uint32 108B dask.array<chunksize=(27,), meta=np.ndarray>
#         │           pixel         (ground_range) uint32 3kB dask.array<chunksize=(663,), meta=np.ndarray>
#         │       Data variables:
#         │           beta_nought   (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           dn            (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           gamma         (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         │           sigma_nought  (azimuth_time, ground_range) float32 72kB dask.array<chunksize=(27, 663), meta=np.ndarray>
#         ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/quality/noise
#         │       Dimensions:                        (azimuth_time: 797)
#         │       Coordinates:
#         │         * azimuth_time                   (azimuth_time) datetime64[ns] 6kB 2025-04-...
#         │       Data variables:
#         │           noise_power_correction_factor  (azimuth_time) float32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
#         │           number_of_noise_lines          (azimuth_time) uint32 3kB dask.array<chunksize=(797,), meta=np.ndarray>
#         ├── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/quality/noise_azimuth
#         │       Dimensions:             (swath: 3, azimuth_time: 1686)
#         │       Coordinates:
#         │           first_azimuth_time  (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
#         │           first_range_sample  (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
#         │           last_azimuth_time   (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
#         │           last_range_sample   (swath) int32 12B dask.array<chunksize=(3,), meta=np.ndarray>
#         │           line                (swath, azimuth_time) int32 20kB dask.array<chunksize=(3, 1686), meta=np.ndarray>
#         │         * swath               (swath) <U3 36B 'IW1' 'IW2' 'IW3'
#         │       Dimensions without coordinates: azimuth_time
#         │       Data variables:
#         │           noise_azimuth_lut   (swath, azimuth_time) float32 20kB dask.array<chunksize=(3, 1686), meta=np.ndarray>
#         └── Group: /S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VV/quality/noise_range
#                 Dimensions:          (azimuth_time: 26, ground_range: 666)
#                 Coordinates:
#                   * azimuth_time     (azimuth_time) datetime64[ns] 208B 2025-04-08T16:49:09.0...
#                     ground_range     (azimuth_time, ground_range) float64 139kB dask.array<chunksize=(26, 666), meta=np.ndarray>
#                     line             (azimuth_time) int32 104B dask.array<chunksize=(26,), meta=np.ndarray>
#                     pixel            (azimuth_time, ground_range) int32 69kB dask.array<chunksize=(26, 666), meta=np.ndarray>
#                 Data variables:
#                     noise_range_lut  (azimuth_time, ground_range) float32 69kB dask.array<chunksize=(26, 666), meta=np.ndarray>

# %% [markdown]
# (OverviewGRD)=
# ## Overview of the product content
#
# The Zarr GRD product contains one group for each polarization:

# %%
dt.groups[1]
# Out:
# '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH'

# %% [markdown]
# Each polarization group contains the `conditions`, `measurements` and `quality` groups. We can list all the groups for the VH polarization calling `.groups`

# %%
dt[dt.groups[1]].groups
# Out:
# ('/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/measurements',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/antenna_pattern',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/attitude',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/azimuth_fm_rate',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/coordinate_conversion',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/doppler_centroid',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/gcp',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/orbit',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/reference_replica',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/replica',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/conditions/terrain_height',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/calibration',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise_azimuth',
#  '/S01SIWGRD_20250408T164909_0025_A335_D5AC_0743A7_VH/quality/noise_range')

# %% [markdown]
# Access now the VH polarization group and the GRD DataArray

# %%
grd = dt[dt.groups[1]]["measurements/grd"]
grd
# Out:
# <xarray.DataArray 'grd' (azimuth_time: 16675, ground_range: 26450)> Size: 882MB
# dask.array<open_dataset-grd, shape=(16675, 26450), dtype=uint16, chunksize=(2048, 4096), chunktype=numpy.ndarray>
# Coordinates:
#   * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2025-04-08T16:49:09.022...
#   * ground_range  (ground_range) float64 212kB 0.0 10.0 ... 2.645e+05 2.645e+05
#     line          (azimuth_time) int64 133kB dask.array<chunksize=(2048,), meta=np.ndarray>
#     pixel         (ground_range) int64 212kB dask.array<chunksize=(4096,), meta=np.ndarray>
# Attributes: (3)

# %% [markdown]
# (LocationGRD)=
# ## Explore product geolocation

# %% [markdown]
# The Zarr product metadata contains information about the product geolocation we can explore in various ways. For instance, we can show the product footprint on an interactive map.

# %%
import geopandas as gpd

# Create a GeoDataFrame from the feature
gdf = gpd.GeoDataFrame.from_features(
    [
        {
            "type": "Feature",
            "geometry": dt.attrs["stac_discovery"][
                "geometry"
            ],  # Use the actual geometry, not the bbox
            "properties": dt.attrs["stac_discovery"][
                "properties"
            ],  # Include all properties
        }
    ],
    crs="EPSG:4326",  # Set the CRS explicitly (adjust EPSG code if needed)
)
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92a4c2ddca4574fa07d67c4e86cd2de5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92a4c2ddca4574fa07d67c4e86cd2de5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92a4c2ddca4574fa07d67c4e86cd2de5 = L.map(
#                 &quot;map_92a4c2ddca4574fa07d67c4e86cd2de5&quot;,
#                 {
#                     center: [40.412212499999995, 16.920439],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_92a4c2ddca4574fa07d67c4e86cd2de5);
#
#
#
#
#
#             var tile_layer_50c2b91b91c09c9d3f850a9f9951759d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50c2b91b91c09c9d3f850a9f9951759d.addTo(map_92a4c2ddca4574fa07d67c4e86cd2de5);
#
#
#             map_92a4c2ddca4574fa07d67c4e86cd2de5.fitBounds(
#                 [[39.456787, 15.213353], [41.367638, 18.627525]],
#                 {}
#             );
#
#
#         function geo_json_77634964feb34c51ce8bb9c8c2ab2c52_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_77634964feb34c51ce8bb9c8c2ab2c52_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_77634964feb34c51ce8bb9c8c2ab2c52_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_77634964feb34c51ce8bb9c8c2ab2c52_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_77634964feb34c51ce8bb9c8c2ab2c52_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_77634964feb34c51ce8bb9c8c2ab2c52.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_77634964feb34c51ce8bb9c8c2ab2c52_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_77634964feb34c51ce8bb9c8c2ab2c52 = L.geoJson(null, {
#                 onEachFeature: geo_json_77634964feb34c51ce8bb9c8c2ab2c52_onEachFeature,
#
#                 style: geo_json_77634964feb34c51ce8bb9c8c2ab2c52_styler,
#                 pointToLayer: geo_json_77634964feb34c51ce8bb9c8c2ab2c52_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_77634964feb34c51ce8bb9c8c2ab2c52_add (data) {
#             geo_json_77634964feb34c51ce8bb9c8c2ab2c52
#                 .addData(data);
#         }
#             geo_json_77634964feb34c51ce8bb9c8c2ab2c52_add({&quot;bbox&quot;: [15.213353, 39.456787, 18.627525, 41.367638], &quot;features&quot;: [{&quot;bbox&quot;: [15.213353, 39.456787, 18.627525, 41.367638], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[15.213353, 40.959007], [18.317894, 41.367638], [18.627525, 39.866714], [15.591434, 39.456787], [15.213353, 40.959007]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;constellation&quot;: &quot;sentinel-1&quot;, &quot;cre

# %% [markdown]
# (DecimationGRD)=
# ### Data Decimation

# %% [markdown]
# We compose a new object, applying decimation to reduce the data we consider for visualization, speeding up the process. Moreover, the original resolution wouldn't fit on most screens. Decimation is performed using the `.isel` xarray method. Here we take one pixel every 10 available in the original dataset:
# ```python
# .isel(x=slice(None, None, 10), y=slice(None, None, 10))
# ```

# %%
# Decimation data
## decimation
grd_decimated = grd.isel(
    azimuth_time=slice(None, None, 10), ground_range=slice(None, None, 10)
)

## plot
grd_decimated.plot(vmax=200)
plt.show()

# %% [markdown]
# (GeocodingGRD)=
# ## Data Geocoding using GCPs
#
# The data we just visualized is in `azimuth_time` and `ground_range` coordinates. However, if we would like to create a map or compare this data with other data sources, we need to perform a _geocoding_ (also known as _geo-referencing_) operation: the data will be interpolated given the reference Ground Control Points (GCPs). GCPs are defined as points on the surface of the Earth of known location used to interpolate and assig new geographic coordinates to the data.
# If you want to know more about Sentinel-1 Geocoding, please refer to this geocoding guide specific for GRD data: https://asf.alaska.edu/wp-content/uploads/2019/02/GeocodingSentinelData_GDAL_v7.1_.pdf
#
# **Please not that this geocoding process does not involve terrain correction.** To match the imagery to actual features on the earth and correct for distortions caused by the side-looking geometry of SAR data, you must perform other steps including terrain correction.

# %% [markdown]
# We firstly need to access the GCPs data:

# %%
gcp = dt[dt.groups[1]]["conditions/gcp"].to_dataset()
gcp
# Out:
# <xarray.Dataset> Size: 12kB
# Dimensions:               (azimuth_time: 10, ground_range: 21)
# Coordinates:
#   * azimuth_time          (azimuth_time) datetime64[ns] 80B 2025-04-08T16:49:...
#   * ground_range          (ground_range) float64 168B 0.0 ... 2.645e+05
#     line                  (azimuth_time) uint32 40B dask.array<chunksize=(10,), meta=np.ndarray>
#     pixel                 (ground_range) uint32 84B dask.array<chunksize=(21,), meta=np.ndarray>
# Data variables:
#     azimuth_time_gcp      (azimuth_time, ground_range) datetime64[ns] 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     elevation_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     height                (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     incidence_angle       (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     latitude              (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     longitude             (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
#     slant_range_time_gcp  (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>

# %% [markdown]
# The GCPs information are provided in a coarser resolution and therefore we need to interpolate them to match the GRD DataArray:

# %%
gcp_iterpolated = gcp.interp_like(grd_decimated)
gcp_iterpolated
# Out:
# <xarray.Dataset> Size: 212MB
# Dimensions:               (azimuth_time: 1668, ground_range: 2645)
# Coordinates:
#     line                  (azimuth_time) float64 13kB dask.array<chunksize=(1668,), meta=np.ndarray>
#     pixel                 (ground_range) float64 21kB dask.array<chunksize=(2645,), meta=np.ndarray>
#   * azimuth_time          (azimuth_time) datetime64[ns] 13kB 2025-04-08T16:49...
#   * ground_range          (ground_range) float64 21kB 0.0 100.0 ... 2.644e+05
# Data variables:
#     elevation_angle       (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>
#     height                (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>
#     incidence_angle       (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>
#     latitude              (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>
#     longitude             (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>
#     slant_range_time_gcp  (azimuth_time, ground_range) float64 35MB dask.array<chunksize=(1668, 2645), meta=np.ndarray>

# %% [markdown]
# Assign the interpolated `latitude` and `longitude` layers to the GRD coordinates:

# %%
grd_decimated = grd_decimated.assign_coords(
    {"latitude": gcp_iterpolated.latitude, "longitude": gcp_iterpolated.longitude}
)

# %% [markdown]
# Finally visualize the geocoded data:

# %%
_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(
    draw_labels=True, crs=ccrs.PlateCarree(), x_inline=False, y_inline=False
)
grd_decimated.plot(
    ax=ax, transform=ccrs.PlateCarree(), x="longitude", y="latitude", vmax=200
)
ax.set_title("Geocoded Sentinel-1 GRD data")
plt.show()

# %% [markdown]
# (SelectionGRD)=
# ## Geographic Selection

# %% [markdown]
# Now that the data is geocoded/georeferenced, it is possible to perform a spatial slicing (or spatial filtering, or cropping) operation, which allows to select only the data falling in our Area Of Interest (AOI):

# %%
lat_max = 40.5
lat_min = 40.25
lon_max = 17
lon_min = 16.5

polygon_lon = [lon_min, lon_max, lon_max, lon_min, lon_min]
polygon_lat = [lat_max, lat_max, lat_min, lat_min, lat_max]

# %% [markdown]
# Crop the data in space, defining a boolean mask and applying it to the data:

# %%
mask = (
    (grd_decimated.latitude < lat_max)
    & (grd_decimated.latitude > lat_min)
    & (grd_decimated.longitude < lon_max)
    & (grd_decimated.longitude > lon_min).compute()
)

# %%
grd_crop = grd_decimated.where(mask.compute(), drop=True)

# %% [markdown]
# Plot the result in geographic coordinates, highlighting the Area Of Interest:

# %%
_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(
    draw_labels=True, crs=ccrs.PlateCarree(), x_inline=False, y_inline=False
)
grd_decimated[::5, ::5].plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    x="longitude",
    y="latitude",
    vmax=200,
)
plt.plot(
    polygon_lon,
    polygon_lat,
    color="red",
    linewidth=2,
    marker="o",
    transform=ccrs.PlateCarree(),
)
ax.set_title("Geocoded Sentinel-1 GRD data, AOI in red")

_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(
    draw_labels=True, crs=ccrs.PlateCarree(), x_inline=False, y_inline=False
)
grd_crop.plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    x="longitude",
    y="latitude",
    vmax=200,
)
ax.set_title("Cropped Sentinel-1 GRD data")

plt.show()

# %% [markdown]
# (SummaryGRD)=
# ## Summary

# %% [markdown]
# This notebook explored Sentinel-1 GRD data: how to open the Zarr product, select specific groups and perform more advanced operations like geocoding.

# %% [markdown]
# <img src='data:image/png;base64,...' />
