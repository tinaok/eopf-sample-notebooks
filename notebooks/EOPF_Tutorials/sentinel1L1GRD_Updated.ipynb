# %% [markdown]
# <img src='data:image/png;base64,...' />

# %% [markdown]
# # SENTINEL-1 L1 GRD Product Format Prototype

# %% [markdown]
# ## Table of Contents
# 1. [Introduction](#Introduction)
# 2. [Import modules](#Import-modules)
# 3. [File path definition](#File-path-definition)
# 4. [Read local files with EOPF](#Read-local-files-with-EOPF)
# 5. [Read remote files with xarray-datatree](#Read-remote-files-with-xarray-datatree)
# 6. [Examples of product usage](#Examples-of-product-usage)
#    [A. Decimation data](#Decimation-data)
#    [B. Geocoding using GCPs](#Geocoding-using-GCPs)
#    [C. Geographic selection](#Geographic-selection)

# %% [markdown]
# ## Introduction
# In this notebook we will show an example of grd TOPSAR product and some easy usage examples
#
#
# **Objectives**:
#    - Provide ready-to-use datasets and data variable
#    - Allow users to open and manipulate data using both standard external tools and the EOPF
#
# **Relevant Features**:
#    - Swaths, bursts and polarization are separeted in different products
#    - The coordinates associated to the data are the physical coordinates
#    - The zarr product will adhere to CF convetion (this allow the user to open the prodoct with standards tools, such as xarray, exploiting properly the data coordinates).
#
# **Notes**:
#
# It is a preliminary example of product
# - Not all the metadata are included in these product prototype, but they will be included in the future.
# - Among the excluded metadata, there are:
#     - RFI
#     - qualityInformation
#     - downlinkInformation
# - The stac attrabutes are still to be defined.
# - The name of the variables are preliminary and they may change in the future.
# - Variable attributes will be refined in the future, including:
#     - long_name
#     - units
#     - and standard names for coordinates
# - The chunking is not defined yet.
# - Products naming convention is to be defined.
# - Reading from local and remote storage with EOPF is experimental(branch feat/coords_in_vars, commit 10a4f2e1) and not officially released.1) and not offically released.

# %% [markdown]
# ## Import modules
#
# Dependencies
#
# - datatree
# - eopf
# - xarray
# - matplotlib
# - cartopy

# %%
# %matplotlib inline

import datatree
import eopf
import xarray as xr
import zarr

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["font.size"] = 10

# %%
import eopf
from eopf.store.zarr import EOZarrStore

# %% [markdown]
# ## File path definition
#
# **GRD**: S1A_IW_GRDH_1SDV_20240201T164915_20240201T164940_052368_065517_750E
#
# **polarization**:VH

# %%
# remote files path
remote_product_path = "s3://sentinel-1-public/demo_product/grd/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr"
remote_product_path = "https://storage.sbg.cloud.ovh.net/v1/AUTH_8471d76cdd494d98a078f28b195dace4/sentinel-1-public/demo_product/grd/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr"

# %% [markdown]
# ## Read local files with EOPF

# %%
# local files
# !mkdir -p /scratch/demo_product/
# !wget -q -r -nc -nH --cut-dirs=5 https://storage.sbg.cloud.ovh.net/v1/AUTH_8471d76cdd494d98a078f28b195dace4/sentinel-1-public/demo_product/grd/ --no-parent -P /scratch/demo_product/grd/ --reject "index.html*"

local_product_path = "/scratch/demo_product/grd/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr"

# %%
store = EOZarrStore('DIR_TO_WRITE_YOUR_PRODUCT/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr')
store = store.open()
store

# %%
store.load()
# Out:
# ---------------------------------------------------------------------------
# StoreLoadFailure                          Traceback (most recent call last)
# File ~/miniconda3/envs/eopf-cpm/lib/python3.11/site-packages/eopf/store/zarr.py:394, in EOZarrStore.load(self, name, **kwargs)
#     393 else:
# --> 394     raise StoreLoadFailure(
#     395         "The root must be an EOContainer or EOProduct and specified in other_metadata/eopf_category",
#     396     )
#     398 # iterate over sub-directories
#
# StoreLoadFailure: The root must be an EOContainer or EOProduct and specified in other_metadata/eopf_category
#
# During handling of the above exception, another exception occurred:
#
# StoreLoadFailure                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 store.load()
#
# File ~/miniconda3/envs/eopf-cpm/lib/python3.11/site-packages/eopf/store/zarr.py:448, in EOZarrStore.load(self, name, **kwargs)
#     445         ds.close()
#     447 except Exception as err:
# --> 448     raise StoreLoadFailure(f"{self.url} can not be loaded due to: {err}")
#     450 # update cache
#     451 self._cache[self.url.path] = root_eoobj
#
# StoreLoadFailure: /home/yadagale/conda_environements/DIR_TO_WRITE_YOUR_PRODUCT/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr can not be loaded due to: The root must be an EOContainer or EOProduct and specified in other_metadata/eopf_category

# %% [markdown]
# ## Read remote files with xarray-datatree
#
# (xarray extension that allow performing operations on hierachical structures)

# %%
dt = datatree.open_datatree(remote_product_path, engine='zarr', chunks={})
dt
# Out:
# DataTree('None', parent=None)
# │   Dimensions:  ()
# │   Data variables:
# │       *empty*
# │   Attributes:
# │       constellation:              sentinel-1
# │       instrument:                 ['c-sar']
# │       platform:                   sentinel-1a
# │       sar:frequency_band:         C
# │       sar:instrument_mode:        IW
# │       sar:observation_direction:  right
# │       sar:polarizations:          ['VH']
# │       sar:product_type:           GRD
# │       sat:absolute_orbit:         52368
# │       sat:anx_datetime:           2024-02-01T16:38:33.596595Z
# │       sat:orbit_state:            ascending
# │       sat:relative_orbit:         146
# ├── DataTree('conditions')
# │   ├── DataTree('attitude')
# │   │       Dimensions:       (azimuth_time: 25)
# │   │       Coordinates:
# │   │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2024-02-01T16:49:15.8750...
# │   │       Data variables:
# │   │           pitch         (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           q0            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           q1            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           q2            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           q3            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           roll          (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           wx            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           wy            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           wz            (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │           yaw           (azimuth_time) float64 200B dask.array<chunksize=(25,), meta=np.ndarray>
# │   │       Attributes:
# │   │           ascending_node_time:    2024-02-01T16:38:33.596595
# │   │           mode:                   IW
# │   │           orbit_number:           52368
# │   │           pass:                   ASCENDING
# │   │           relative_orbit_number:  146
# │   │           title:                  Attitude information used by the IPF during proce...
# │   ├── DataTree('azimuth_fm_rate')
# │   │       Dimensions:                     (azimuth_time: 10, degree: 3)
# │   │       Coordinates:
# │   │         * azimuth_time                (azimuth_time) datetime64[ns] 80B 2024-02-01T...
# │   │         * degree                      (degree) int64 24B 0 1 2
# │   │       Data variables:
# │   │           azimuth_fm_rate_polynomial  (azimuth_time, degree) float64 240B dask.array<chunksize=(10, 3), meta=np.ndarray>
# │   │           t0                          (azimuth_time) float64 80B dask.array<chunksize=(10,), meta=np.ndarray>
# │   ├── DataTree('coordinate_conversion')
# │   │       Dimensions:           (azimuth_time: 28, degree: 9)
# │   │       Coordinates:
# │   │         * azimuth_time      (azimuth_time) datetime64[ns] 224B 2024-02-01T16:49:13....
# │   │         * degree            (degree) int64 72B 0 1 2 3 4 5 6 7 8
# │   │       Data variables:
# │   │           gr0               (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │           grsrCoefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
# │   │           slant_range_time  (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │           sr0               (azimuth_time) float64 224B dask.array<chunksize=(28,), meta=np.ndarray>
# │   │           srgrCoefficients  (azimuth_time, degree) float64 2kB dask.array<chunksize=(28, 9), meta=np.ndarray>
# │   ├── DataTree('doppler_centroid')
# │   │       Dimensions:                            (azimuth_time: 27, degree: 3)
# │   │       Coordinates:
# │   │         * azimuth_time                       (azimuth_time) datetime64[ns] 216B 202...
# │   │         * degree                             (degree) int64 24B 0 1 2
# │   │       Data variables:
# │   │           data_dc_polynomial                 (azimuth_time, degree) float64 648B dask.array<chunksize=(27, 3), meta=np.ndarray>
# │   │           data_dc_rms_error                  (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │           data_dc_rms_error_above_threshold  (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │           fine_dce_azimuth_start_time        (azimuth_time) datetime64[ns] 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │           fine_dce_azimuth_stop_time         (azimuth_time) datetime64[ns] 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   │           geometry_dc_polynomial             (azimuth_time, degree) float64 648B dask.array<chunksize=(27, 3), meta=np.ndarray>
# │   │           t0                                 (azimuth_time) float64 216B dask.array<chunksize=(27,), meta=np.ndarray>
# │   ├── DataTree('gcp')
# │   │       Dimensions:           (azimuth_time: 10, ground_range: 21)
# │   │       Coordinates:
# │   │         * azimuth_time      (azimuth_time) datetime64[ns] 80B 2024-02-01T16:49:15.7...
# │   │         * ground_range      (ground_range) float64 168B 0.0 1.323e+04 ... 2.646e+05
# │   │           line              (azimuth_time) int64 80B dask.array<chunksize=(10,), meta=np.ndarray>
# │   │           pixel             (ground_range) int64 168B dask.array<chunksize=(21,), meta=np.ndarray>
# │   │           slant_range_time  (ground_range) float64 168B dask.array<chunksize=(21,), meta=np.ndarray>
# │   │       Data variables:
# │   │           elevationAngle    (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │           height            (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │           incidenceAngle    (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │           latitude          (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   │           longitude         (azimuth_time, ground_range) float64 2kB dask.array<chunksize=(10, 21), meta=np.ndarray>
# │   ├── DataTree('orbit')
# │   │       Dimensions:       (axis: 3, azimuth_time: 16)
# │   │       Coordinates:
# │   │         * axis          (axis) int64 24B 0 1 2
# │   │         * azimuth_time  (azimuth_time) datetime64[ns] 128B 2024-02-01T16:48:13.6102...
# │   │       Data variables:
# │   │           position      (axis, azimuth_time) float64 384B dask.array<chunksize=(3, 16), meta=np.ndarray>
# │   │           velocity      (axis, azimuth_time) float64 384B dask.array<chunksize=(3, 16), meta=np.ndarray>
# │   │       Attributes:
# │   │           ascending_node_time:    2024-02-01T16:38:33.596595
# │   │           mode:                   IW
# │   │           orbit_number:           52368
# │   │           pass:                   ASCENDING
# │   │           reference_system:       Earth Fixed
# │   │           relative_orbit_number:  146
# │   │           title:                  Orbit information used by the IPF during processing
# │   ├── DataTree('reference_replica')
# │   │       Dimensions:                                   (degree: 4)
# │   │       Coordinates:
# │   │         * degree                                    (degree) int64 32B 0 1 2 3
# │   │       Data variables:
# │   │           reference_replica_amplitude_coefficients  (degree) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
# │   │           reference_replica_phase_coefficients      (degree) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
# │   │       Attributes:
# │   │           azimuth_time:  2024-02-01T16:49:14.330144
# │   │           chirp_source:  Nominal
# │   │           gain:          {'im': 0.0, 're': 1.0}
# │   │           pg_source:     Extracted
# │   │           time_delay:    4.364615e-07
# │   └── DataTree('replica')
# │           Dimensions:                           (azimuth_time: 15)
# │           Coordinates:
# │             * azimuth_time                      (azimuth_time) datetime64[ns] 120B 2024...
# │           Data variables:
# │               absolute_pg_product_valid_flag    (azimuth_time) int8 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │               cross_correlation_bandwidth       (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               cross_correlation_peak_location   (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               cross_correlation_pslr            (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               internal_time_delay               (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               model_pg_product_amplitude        (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               model_pg_product_phase            (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               pg_product_amplitude              (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               pg_product_phase                  (azimuth_time) float64 120B dask.array<chunksize=(15,), meta=np.ndarray>
# │               reconstructed_replica_valid_flag  (azimuth_time) int8 15B dask.array<chunksize=(15,), meta=np.ndarray>
# │               relative_pg_product_valid_flag    (azimuth_time) int8 15B dask.array<chunksize=(15,), meta=np.ndarray>
# ├── DataTree('measurements')
# │       Dimensions:       (azimuth_time: 16675, ground_range: 26456)
# │       Coordinates:
# │         * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2024-02-01T16:49:15.722...
# │         * ground_range  (ground_range) float64 212kB 0.0 10.0 ... 2.645e+05 2.646e+05
# │           line          (azimuth_time) int64 133kB dask.array<chunksize=(16675,), meta=np.ndarray>
# │           pixel         (ground_range) int64 212kB dask.array<chunksize=(26456,), meta=np.ndarray>
# │       Data variables:
# │           grd           (azimuth_time, ground_range) float32 2GB dask.array<chunksize=(16675, 26456), meta=np.ndarray>
# │       Attributes: (12/30)
# │           Conventions:                         CF-1.8
# │           ascending_node_time:                 2024-02-01T16:38:33.596595
# │           azimuth_pixel_spacing:               10.0
# │           azimuth_time_interval:               0.001499231873605405
# │           family_name:                         SENTINEL-1
# │           geospatial_bounds:                   POLYGON((18.62418337217432 39.866520...
# │           ...                                  ...
# │           relative_orbit_number:               146
# │           start_time:                          2024-02-01T16:49:15.722819
# │           stop_time:                           2024-02-01T16:49:40.721011
# │           subgroups:                           ['orbit', 'attitude', 'azimuth_fm_ra...
# │           swaths:                              ['IW']
# │           transmitter_receiver_polarisations:  ['VH']
# └── DataTree('quality')
#     ├── DataTree('calibration')
#     │       Dimensions:       (azimuth_time: 25, ground_range: 663)
#     │       Coordinates:
#     │         * azimuth_time  (azimuth_time) datetime64[ns] 200B 2024-02-01T16:49:15.7228...
#     │         * ground_range  (ground_range) float64 5kB 0.0 400.0 ... 2.644e+05 2.646e+05
#     │           line          (azimuth_time) int64 200B dask.array<chunksize=(25,), meta=np.ndarray>
#     │           pixel         (ground_range) int64 5kB dask.array<chunksize=(663,), meta=np.ndarray>
#     │       Data variables:
#     │           beta_nought   (azimuth_time, ground_range) float32 66kB dask.array<chunksize=(25, 663), meta=np.ndarray>
#     │           dn            (azimuth_time, ground_range) float32 66kB dask.array<chunksize=(25, 663), meta=np.ndarray>
#     │           gamma         (azimuth_time, ground_range) float32 66kB dask.array<chunksize=(25, 663), meta=np.ndarray>
#     │           sigma_nought  (azimuth_time, ground_range) float32 66kB dask.array<chunksize=(25, 663), meta=np.ndarray>
#     │       Attributes:
#     │           absolute_calibration_constant:  1.0
#     ├── DataTree('noise_azimuth')
#     │       Dimensions:            (azimuth_time: 1684)
#     │       Coordinates:
#     │         * azimuth_time       (azimuth_time) datetime64[ns] 13kB 2024-02-01T16:49:15...
#     │           line               (azimuth_time) int64 13kB dask.array<chunksize=(1684,), meta=np.ndarray>
#     │       Data variables:
#     │           noise_azimuth_lut  (azimuth_time) float32 7kB dask.array<chunksize=(1684,), meta=np.ndarray>
#     └── DataTree('noise_range')
#             Dimensions:        (azimuth_time: 26, ground_range: 666)
#             Coordinates:
#               * azimuth_time   (azimuth_time) datetime64[ns] 208B 2024-02-01T16:49:15.722...
#               * ground_range   (ground_range) float64 5kB 0.0 400.0 ... 2.642e+05 2.646e+05
#                 line           (azimuth_time) int64 208B dask.array<chunksize=(26,), meta=np.ndarray>
#                 pixel          (ground_range) int64 5kB dask.array<chunksize=(666,), meta=np.ndarray>
#             Data variables:
#                 noiseRangeLut  (azimuth_time, ground_range) float32 69kB dask.array<chunksize=(26, 666), meta=np.ndarray>

# %% [markdown]
# ## Examples of product usage

# %%
# open data with xarray
grd = xr.open_dataset(remote_product_path, group=f"measurements", engine="zarr")["grd"]

# %% [markdown]
# ### Decimation data

# %%
# Decimation data
## decimation
grd_decimated = grd.isel(azimuth_time=slice(None, None, 10), ground_range=slice(None, None, 10))

## plot
grd_decimated.plot(vmax=200)
## if not able to see the image then use the below line
plt.show()

# %% [markdown]
# ### Geocoding using GCPs
# **Interpolate and assign new geographic coordinates**

# %%
# Geocoding using GCP's
## interpolate and assig new geografic coordinates
gcp = xr.open_dataset(remote_product_path, group=f"conditions/gcp", engine="zarr")
gcp_iterpolated = gcp.interp_like(grd_decimated)

grd_decimated = grd_decimated.assign_coords({"latitude": gcp_iterpolated.latitude, "longitude": gcp_iterpolated.longitude})

# %% [markdown]
# **Plot in geographic coordinates**

# %%
## plot in geographic coordinates
import cartopy.crs as ccrs
_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(draw_labels=True,crs=ccrs.PlateCarree(), x_inline=False, y_inline=False)
grd_decimated.plot(
    ax=ax, 
    transform=ccrs.PlateCarree(),
    x="longitude", 
    y="latitude",
    vmax=200
)
## if not able to see the image then use the below line
plt.show()

# %% [markdown]
# ### Geographic selection
# **Region definition**

# %%
lat_max = 40.5
lat_min = 40.25
lon_max = 17
lon_min = 16.5

polygon_lon = [lon_min, lon_max, lon_max, lon_min, lon_min]
polygon_lat = [lat_max, lat_max, lat_min, lat_min, lat_max]

# %% [markdown]
# **Crop using lon lat coordinates**

# %%
## crop using lat lon coordinates
mask = (grd_decimated.latitude < lat_max) & \
    (grd_decimated.latitude > lat_min) & \
    (grd_decimated.longitude < lon_max) & \
    (grd_decimated.longitude > lon_min)
grd_crop = grd_decimated.where(mask, drop=True)

# %% [markdown]
# **Plot in geographic coordinates**

# %%
## plot in geographic coordinates
_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(draw_labels=True,crs=ccrs.PlateCarree(), x_inline=False, y_inline=False)
grd_decimated[::5, ::5].plot(
    ax=ax, 
    transform=ccrs.PlateCarree(),
    x="longitude", 
    y="latitude",
    vmax=200,
)
plt.plot(
    polygon_lon,
    polygon_lat,
    color='red', linewidth=2, marker='o',
    transform=ccrs.PlateCarree(),
)


_, ax = plt.subplots(subplot_kw={"projection": ccrs.Miller()}, figsize=(12, 8))
gl = ax.gridlines(draw_labels=True,crs=ccrs.PlateCarree(), x_inline=False, y_inline=False)
grd_crop.plot(
    ax=ax, 
    transform=ccrs.PlateCarree(),
    x="longitude", 
    y="latitude",
    vmax=200,
)
## if not able to see the image then use the below line
plt.show()
