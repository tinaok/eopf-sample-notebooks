# %% [markdown]
# <img src="https://raw.githubusercontent.com/EOPF-Sample-Service/sample-notebooks/refs/heads/main/notebooks/template/assets/ESA_logo_2020_Deep.png"
#      alt="ESA logo"
#      style="float: center; margin-right: 10px; width: 600px;" />

# %% [markdown]
# # Title
#
# ## Version
# Release date: 29-01-2025
#
# Update date: 29-01-2025
#
# ## License
# This notebook is distributed under the [Apache 2.0 License](https://www.apache.org/licenses/LICENSE-2.0.txt)
#
# ## Authors
# Michele Claus <a href="https://orcid.org/0000-0003-3680-381X" aria-label="View ORCID record">
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/06/ORCID_iD.svg"
#      alt="ORCID iD"
#      style="width: 24px;"/></a>,
#      Second Author <a href="https://orcid.org/0000-0003-3680-381X" aria-label="View ORCID record">
# <img src="https://upload.wikimedia.org/wikipedia/commons/0/06/ORCID_iD.svg"
#      alt="ORCID iD"
#      style="width: 24px;"/></a>
#
# ## Table of contents
#
# - [Introduction](#Introduction)
# - [Setup](#Setup)
# - [Read EOPF-Zarr](#Read-EOPF-Zarr)

# %% [markdown]
# ## Introduction
#
# Insert here the notebook description

# %% [markdown]
# <div class="alert alert-info">
# <i class="fa-question-circle fa" style="font-size: 22px;color:#666;"></i> <b>Overview</b>
#     <br>
#     <br>
#     <b>Questions</b>
#     <ul>
#         <li>What is this notebook doing?</li>
#         <li>Why is it useful?</li>
#     </ul>
#     <b>Objectives</b>
#     <ul>
#         <li>Objective 1</li>
#         <li>Objective 2</li>
#     </ul>
# </div>

# %% [markdown]
# ## Setup
# Start importing the necessary libraries

# %%
import xarray as xr

# %% [markdown]
# ## Read EOPF Zarr
# Sample code reading a Sentinel-1 GRD product from https using xarray

# %%
remote_product_path = "https://storage.sbg.cloud.ovh.net/v1/AUTH_8471d76cdd494d98a078f28b195dace4/sentinel-1-public/demo_product/grd/S01SIWGRH_20240201T164915_0025_A146_S000_5464A_VH.zarr"
grd = xr.open_dataset(remote_product_path, group=f"measurements", engine="zarr")["grd"]
grd
# Out:
# <xarray.DataArray 'grd' (azimuth_time: 16675, ground_range: 26456)> Size: 2GB
# [441153800 values with dtype=float32]
# Coordinates:
#   * azimuth_time  (azimuth_time) datetime64[ns] 133kB 2024-02-01T16:49:15.722...
#   * ground_range  (ground_range) float64 212kB 0.0 10.0 ... 2.645e+05 2.646e+05
#     line          (azimuth_time) int64 133kB ...
#     pixel         (ground_range) int64 212kB ...
# Attributes: (12/28)
#     ascending_node_time:                 2024-02-01T16:38:33.596595
#     azimuth_pixel_spacing:               10.0
#     azimuth_time_interval:               0.001499231873605405
#     family_name:                         SENTINEL-1
#     geospatial_bounds:                   POLYGON((18.62418337217432 39.866520...
#     geospatial_lat_max:                  41.36716535718914
#     ...                                  ...
#     relative_orbit_number:               146
#     start_time:                          2024-02-01T16:49:15.722819
# ...
